-- %%
select current_metastore();

-- %%
%fs ls 'abfss://demo@ourdbpracticeextdl.dfs.core.windows.net/'

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS dea_course_ext_dl_demo
  URL 'abfss://demo@ourdbpracticeextdl.dfs.core.windows.net/'
  WITH (STORAGE CREDENTIAL dae_course_ext_sc
)
  COMMENT 'test this';
