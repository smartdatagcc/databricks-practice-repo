-- %% [markdown]
-- ### Query orders data as json strings
-- ##### 1. Extract top level column values
-- ##### 2. Extract array elements
-- ##### 3. Extract nested column values
-- ##### 4. CAST Column values to a specific data type

-- %%
select * 



from gizmobox_catalog_noori.bronze.v_orders

-- %%
select 
value:order_id as order_id,
value

from gizmobox_catalog_noori.bronze.v_orders

-- %%
select 
value:items as items,
value

from gizmobox_catalog_noori.bronze.v_orders

-- %%
select 
value:items[0] as items_1,
value:items[1] as items_2,
value

from gizmobox_catalog_noori.bronze.v_orders

-- %%
select 
value:items[0].item_id as items_1_id,
value:items[0]as items_1,
value

from gizmobox_catalog_noori.bronze.v_orders

-- %%
select 
value:items[0].item_id::int as items_1_id,
value:items[0]as items_1,
value

from gizmobox_catalog_noori.bronze.v_orders
