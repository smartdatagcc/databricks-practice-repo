-- %% [markdown]
-- # Extract Data

-- %% [markdown]
-- ## Query Single json file

-- %%
%fs ls /Volumes/gizmobox_catalog_noori/landing/vol_operational_data/customers

-- %%
select * from json.`/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/customers/customers_2024_10.json`

-- %%
select * from json.`/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/customers/customers_2024*.json`

-- %%
select * from json.`/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/customers/`

-- %%
select input_file_name() as path, 
_metadata.file_path,

* from json.`/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/customers/`

-- %%
create or replace view gizmobox_catalog_noori.bronze.v_customers as
select 
*, _metadata.file_path as filepath from json.`/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/customers/`

-- %%
select * from gizmobox_catalog_noori.bronze.v_customers;

-- %%
create or replace temporary view ttv_customers as
select 
*, _metadata.file_path as filepath from json.`/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/customers/`

-- %%
select * from gizmobox_catalog_noori.bronze.v_customers;

-- %%
create or replace global temporary view gizmobox_catalog_noori.bronze.gtv_customers as
select 
*, _metadata.file_path as filepath from json.`/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/customers/`
