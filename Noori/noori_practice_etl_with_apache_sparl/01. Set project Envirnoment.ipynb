-- %% [markdown]
-- # 1. Access the container databrickspracticecontainer

-- %%
%fs ls 'abfss://databrickspracticecontainer@databricksstgnoori.dfs.core.windows.net/Landing/'

-- %%
%fs ls 'abfss://databrickspracticecontainer@databricksstgnoori.dfs.core.windows.net/Landing/external_data/'

-- %%
%fs ls 'abfss://databrickspracticecontainer@databricksstgnoori.dfs.core.windows.net/Landing/operational_data/'

-- %% [markdown]
-- ## 2. Create External location

-- %%
%sql
CREATE EXTERNAL LOCATION IF NOT EXISTS databricks_practice_noori_ext_loc
    URL 'abfss://databrickspracticecontainer@databricksstgnoori.dfs.core.windows.net'
    WITH (STORAGE CREDENTIAL `databricks_practice_noori`)
    COMMENT 'External Location for practice purpose'

-- %% [markdown]
-- # Create Catalog - gizmobox_noori

-- %%
show catalogs

-- %%
%sql
CREATE CATALOG IF NOT EXISTS gizmobox_catalog_noori
MANAGED LOCATION 'abfss://databrickspracticecontainer@databricksstgnoori.dfs.core.windows.net/'
COMMENT 'this is a gizmobox catalog created for noori'

-- %%
show catalogs

-- %% [markdown]
-- # Create schemas
-- 1. Landing
-- 2. Bronze
-- 3. Silver
-- 4. Gold

-- %%
select current_catalog();

-- %%
use catalog gizmobox_catalog_noori

-- %%
select current_catalog();

-- %%
use catalog gizmobox_catalog_noori;

CREATE SCHEMA  IF NOT EXISTS  landing
     MANAGED LOCATION 'abfss://databrickspracticecontainer@databricksstgnoori.dfs.core.windows.net/';

CREATE SCHEMA  IF NOT EXISTS  bronze
     MANAGED LOCATION 'abfss://databrickspracticecontainer@databricksstgnoori.dfs.core.windows.net/';

CREATE SCHEMA  IF NOT EXISTS  silver
     MANAGED LOCATION 'abfss://databrickspracticecontainer@databricksstgnoori.dfs.core.windows.net/';

CREATE SCHEMA  IF NOT EXISTS  gold
     MANAGED LOCATION 'abfss://databrickspracticecontainer@databricksstgnoori.dfs.core.windows.net/';

-- %%
show schemas;

-- %% [markdown]
-- ## Create Volume

-- %%
use catalog gizmobox_catalog_noori;
use schema landing;

CREATE  EXTERNAL  VOLUME  IF NOT EXISTS  vol_operational_data
     LOCATION  'abfss://databrickspracticecontainer@databricksstgnoori.dfs.core.windows.net/Landing/operational_data/'

-- %%
show volumes

-- %%
%fs ls /Volumes/gizmobox_catalog_noori/landing/vol_operational_data

-- %%
%fs ls /Volumes/gizmobox_catalog_noori/landing/vol_operational_data/customers
