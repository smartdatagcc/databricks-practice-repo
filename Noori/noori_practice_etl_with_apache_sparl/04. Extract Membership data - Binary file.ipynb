-- %% [markdown]
-- # Extract data from the memberships - image files

-- %% [markdown]
-- ## query memberships folder using binaryfile format

-- %%
%fs ls '/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/memberships/'

-- %% [markdown]
-- ## Create memberships view in the bronze later

-- %%
select * from binaryfile.`/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/memberships/*/*.png`

-- %%
create or replace view gizmobox_catalog_noori.bronze.v_memberships as
select * from binaryfile.`/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/memberships/*/*.png`

-- %%
select * from gizmobox_catalog_noori.bronze.v_memberships
