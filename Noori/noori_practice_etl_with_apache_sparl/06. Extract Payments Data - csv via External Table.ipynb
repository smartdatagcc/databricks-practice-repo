-- %% [markdown]
-- # 06. Extract Payments Data - csv via External Table
--
-- ## 1. List the files from payment folder
-- ## 2. Create external table
-- ## 3. deomonstrate the effect of adding / updating / deleteing files
-- ## 4. Demonstrate the effect of dropping the table

-- %%
%fs ls 'abfss://databrickspracticecontainer@databricksstgnoori.dfs.core.windows.net/Landing/external_data/payments/'

-- %%
create table if not exists gizmobox_catalog_noori.bronze.payments
(payment_id integer, order_id integer, payment_timestamp timestamp, palyment_status integer, payment_method string)
using csv
options (
  header = true,
  delimiter = ','
)
location 'abfss://databrickspracticecontainer@databricksstgnoori.dfs.core.windows.net/Landing/external_data/payments/'

-- %%
select * from gizmobox_catalog_noori.bronze.payments

-- %%
describe extended gizmobox_catalog_noori.bronze.payments

-- %% [markdown]
-- ### # add update or delete

-- %%
select count(*) from gizmobox_catalog_noori.bronze.payments

-- %%
refresh table gizmobox_catalog_noori.bronze.payments

-- %%
drop table if exists gizmobox_catalog_noori.bronze.payments
