# %% [markdown]
# ### Extract Data From the Customers JSON File
#  - Query Single File
#  - Query List of Files using Wildcard characters
#  - Query all the files in a folder
#  - Select File Metadata
#  - Register Files in Unity Catalog using Views
#  - Create Temporary View
#  - Create Global Temporary View

# %% [markdown]
# ## Query Single json file

# %%
# %fs ls /Volumes/gizmobox_catalog_noori/landing/vol_operational_data/customers

# %%
# %python
df = spark.read.format('json').load("/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/customers/customers_2024_10.json")
display(df)

# %%
# %python
df = spark.read.format('json').load("/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/customers/customers_2024_10.json")
display(df)

df1 = spark.read.json("/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/customers/customers_2024_10.json")
display(df1)

# %% [markdown]
# query multiple json files

# %%
# %python
df = spark.read.format('json').load("/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/customers/customers_2024_*.json")
display(df)

# %%
# %python
df = spark.read.format('json').load("/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/customers/customers_*.json")
display(df)

# %%
# %python
df = spark.read.format('json').load("/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/customers")
display(df)

# %%
# %python
# df = spark.read.format('json').load("/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/customers")
df1 = df.select("_metadata.file_path","*")
display(df1)

# %%
# %python
df.writeTo("gizmobox_catalog_noori.bronze.py1_customers").createOrReplace()

# %%
# %sql
select * from gizmobox_catalog_noori.bronze.py1_customers

# %%
df = spark.table("gizmobox_catalog_noori.bronze.py1_customers")
display(df)
