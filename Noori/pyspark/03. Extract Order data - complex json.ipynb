# %% [markdown]
# # 03. Extract Order data - complex json

# %% [markdown]
# ## 1. Query Orders file using JSON Format

# %%
df = spark.read.format("json").load("/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/orders/")
display(df)

#Here are the DataFrames in the session:
#-

# %%
df = spark.read.format("text").load("/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/orders/")
display(df)

# %%
df = spark.read.text("/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/orders/")
display(df)

# %%
df.writeTo("gizmobox_catalog_noori.bronze.orders").createOrReplace()

# %%
df =spark.sql("select * from gizmobox_catalog_noori.bronze.orders")
display(df)

# %%
df =spark.table("gizmobox_catalog_noori.bronze.orders")
display(df)

# %%
# %fs ls 'abfss://databrickspracticecontainer@databricksstgnoori.dfs.core.windows.net/Landing/external_data/payments/'

# %%
# %sql
create table gizmobox_catalog_noori.bronze.payments
(payment_id integer, order_id integer, payment_timestamp timestamp, payment_status integer,payment_menthod string)
using csv
options ( header "true", delimeter ",")
location 'abfss://databrickspracticecontainer@databricksstgnoori.dfs.core.windows.net/Landing/external_data/payments/'

# %%
# %sql
select * from gizmobox_catalog_noori.bronze.payments
