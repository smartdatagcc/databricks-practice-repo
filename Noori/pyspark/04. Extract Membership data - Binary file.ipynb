-- %% [markdown]
-- # Extract data from the memberships - image files

-- %% [markdown]
-- ## query memberships folder using binaryfile format

-- %%
%fs ls '/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/memberships/'

-- %% [markdown]
-- ## Create memberships view in the bronze later

-- %%
%python
df = spark.read.format('binaryFile').load('/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/memberships/*/*.png')
display(df)

-- %%
%python
df = spark.read.format('binaryFile').load('/Volumes/gizmobox_catalog_noori/landing/vol_operational_data/memberships/*/*.png')
display(df)

-- %%
%python
df.writeTo("gizmobox_catalog_noori.bronze.py1_memberships").createOrReplace()

-- %%
%python
df = spark.read.table("gizmobox_catalog_noori.bronze.py1_memberships")
display(df)
