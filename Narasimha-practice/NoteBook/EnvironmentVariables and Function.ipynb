# %%
env = 'dev'

# %%
import os
import platform

def print_env_info():
    print(f"Python version: {platform.python_version()}")
    print(f"Spark version: {spark.version}")
    print(f"Running on: {spark.conf.get('spark.databricks.clusterUsageTags.sparkVersion')}")    
print_env_info()
