# %% [markdown]
# - %python,%Scala,%SQL: used to switch between languages in notebook
# - %md: used to document the Notebook
# - %fs: runs the file system commands
# - %sh: runs shell commands(Drive node only)
# - %pip: install python libraries
# - %run: include/import another notebook into currentnotebook

# %%
# %fs
ls /databricks-datasets/

# %%
# %sh ps

# %%
# %pip list

# %%
# %run "/Workspace/Repos/cloud-admin@smartdataglobal.in/databricks-practice-repo/Narasimha-practice/NoteBook/EnvironmentVariables and Function"
