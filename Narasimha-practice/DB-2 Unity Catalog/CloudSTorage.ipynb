# %% [markdown]
# # Access To Cloud Storage

# %%
# %fs ls 'abfss://demo-nara@ourdbpracticeextdl.dfs.core.windows.net/'

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `dae-extrnl-demo-nara`
    URL 'abfss://demo-nara@ourdbpracticeextdl.dfs.core.windows.net/'
    WITH (STORAGE CREDENTIAL `databricks-practice-ext-sc`)
    COMMENT 'External Location demo'

# %%
# %fs ls 'abfss://demo-nara@ourdbpracticeextdl.dfs.core.windows.net/'
