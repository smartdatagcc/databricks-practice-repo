# %% [markdown]
# ## For each of the customer, produce the following summary per month
# ### 1.total orders
# ### 2.total items brought
# ### 3.total amount spent

# %%
# %sql
SELECT * FROM gizmobox_nara.silver.orders where customer_id = 5816

# %%
# %sql
CREATE TABLE IF NOT EXISTS gizmobox_nara.gold.order_summary_monthly
AS
SELECT date_format(transaction_timestamp, 'yyyy-MM') AS order_month,
customer_id,
COUNT(DISTINCT order_id) As Total_orders,
SUM(quantity) AS total_items_bought,
SUM(price * quantity) AS total_amount
FROM gizmobox_nara.silver.orders
GROUP BY order_month, customer_id;

# %%
# %sql
SELECT * FROM gizmobox_nara.gold.order_summary_monthly
