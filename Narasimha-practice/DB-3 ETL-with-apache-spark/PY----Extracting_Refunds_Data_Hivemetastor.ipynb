# %% [markdown]
# # EXTRACT REFUND DATA FROM SQL TABLE(Currently not Hive_metastore)
# ###  Creating Bronze Schema in Hive_Metastore
# ###  Creating External Table

# %% [markdown]
# # creating bronze Schema in Hive_Metastore(Not Working)

# %%
df = (
    spark.read.format('jdbc')
    .option('url', 'jdbc:sqlserver://gizmobox-practice-server.database.windows.net:1433;database=gizmobox-practice-db')
    .option('dbtable', 'RefundsNara')
    .option('user', 'gizmoboxadmin')
    .option('password', 'Databricks@123')
    .load()
)
display(df
)

# %%
df.writeTo('gizmobox_nara.bronze.py_refunds').createOrReplace()

# %%
# %sql
select * FROM gizmobox_nara.bronze.py_refunds

# %% [markdown]
# ### Creating External Table( not working)

# %%
# %sql
CREATE TABLE IF NOT EXISTS hive_metastore.bronze.refunds
USING JDBC
OPTIONS (
    url 'jdbc:sqlserver://gizmobox-practice-server.database.windows.net:1433;database=gizmobox-practice-db',
    dbtable 'RefundsNara',
    user 'gizmobox-practice',
    password ''
)
