# %% [markdown]
# ### 1.User Defined Functions (UDF) in Spark are custom functions created by users to extend the capabilities of Spark SQL and PySpark.
# ### 2.UDFs allow us to perform caluculations or transformations to apply busineess logic that are not possible with built-in functions
# ### 3. You define the function Once and use it accross multiple queries.
# ### 4.SQL UDFs are recommended over Python UDFs due ti better optimization

# %% [markdown]
# SYNTAX
# ### CREATE FUNCTION catalog_name.udf_name(param_name data_type)
# ### RETURN return_type
# ### RETURN expression;
