# %% [markdown]
# ### Transform_MemberShip_Data
# ### 1.Extracting Customer_id from file Pat
# ### 2. Transform to silver layer

# %%
# %sql
SELECT * FROM gizmobox_nara.bronze.v_memberships

# %%
# %sql
SELECT regexp_extract(path, '.*/([0-9]+).png$', 1) AS customer_id,content FROM gizmobox_nara.bronze.v_memberships

# %%
# %sql
CREATE TABLE gizmobox_nara.silver.memberships USING delta AS SELECT regexp_extract(path, '.*/([0-9]+).png$', 1) AS customer_id,content FROM gizmobox_nara.bronze.v_memberships
;
SELECT * FROM gizmobox_nara.silver.memberships
