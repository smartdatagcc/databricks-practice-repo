# %% [markdown]
# #### Extract Data From the Returns SQL Table
# 1. Read Returns data via JDBC
# 2. Create Returns table in Bronze Schema

# %% [markdown]
# #####  1. Read Returns data via JDBC

# %%
df = ( 
    spark.read.format('jdbc')
    .option('url','jdbc:sqlserver://gizmobox-practice-server.database.windows.net:1433;database=gizmobox-practice-db')
    .option('dbtable','refunds')
    .option('user','gizmoboxadmin')
    .option('password','Databricks@123')
    .load()
)
display(df)

# %% [markdown]
# ##### 2. Create Returns table in Bronze Schema

# %%
df.writeTo('gizmobox_catalog_subbu.bronze.py_refunds').createOrReplace()

# %%
# %sql
select * from gizmobox_catalog_subbu.bronze.py_refunds
