-- %% [markdown]
-- 1. List the files form Payment Folder
-- 2. Create External Table
-- 3. Demonstrate the effect of Adding/Updating/Deleting files
-- 4. Demonstrate Efect of Dropping the table

-- %% [markdown]
-- ##### 1. List the files form Payment Folder

-- %%
%fs ls 'abfss://gizmoboxsubbu@ourdbpracticeextdl.dfs.core.windows.net/landing/external_data/payments/'

-- %%
select * from csv.`abfss://gizmoboxsubbu@ourdbpracticeextdl.dfs.core.windows.net/landing/external_data/payments/*.csv`

-- %% [markdown]
-- ##### 2. Create External Table

-- %%
CREATE TABLE IF NOT EXISTS gizmobox_catalog_subbu.bronze.payments
(payment_id INTEGER, order_id INTEGER, payment_timestamp TIMESTAMP, payment_status INTEGER, payment_method STRING)
USING CSV
OPTIONS (
  header = "true",
  DELIMITER = ","  
)
LOCATION 'abfss://gizmoboxsubbu@ourdbpracticeextdl.dfs.core.windows.net/landing/external_data/payments'

-- %%
select * from gizmobox_catalog_subbu.bronze.payments

-- %%
DESCRIBE EXTENDED gizmobox_catalog_subbu.bronze.payments

-- %% [markdown]
-- ##### 3. Demonstrate the effect of Adding/Updating/Deleting files

-- %%
select * from gizmobox_catalog_subbu.bronze.payments

-- %%
REFRESH TABLE gizmobox_catalog_subbu.bronze.payments
--select * from gizmobox_catalog_subbu.bronze.payments

-- %% [markdown]
-- ##### 4. Demonstrate Efect of Dropping the table

-- %%
DROP TABLE IF EXISTS gizmobox_catalog_subbu.bronze.payments
