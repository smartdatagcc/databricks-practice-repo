-- %% [markdown]
-- #### Extract Data From Orders Data - Complex JSON
-- 1. Querying Orders File using JSON Format
-- 2. Query Orders File using TEXT Format
-- 3. Create Orders View in Bronze Schema

-- %% [markdown]
-- ##### 1. Querying Orders File using JSON Format

-- %%
Select * from json.`/Volumes/gizmobox_catalog_subbu/landing/operational_data_volume/orders/`

-- %% [markdown]
-- ##### 2. Query Orders File using TEXT Format

-- %%
Select * from text.`/Volumes/gizmobox_catalog_subbu/landing/operational_data_volume/orders/`

-- %% [markdown]
-- ##### 3. Create Orders View in Bronze Schema

-- %%
Create or replace View gizmobox_catalog_subbu.bronze.v_orders as
select * from text.`/Volumes/gizmobox_catalog_subbu/landing/operational_data_volume/orders`

-- %%
Select * from gizmobox_catalog_subbu.bronze.v_orders
