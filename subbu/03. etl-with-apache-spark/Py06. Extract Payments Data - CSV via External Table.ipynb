# %% [markdown]
# #### Extract Data From the Payments Files
# 1. Read Payments File
# 2. Create Payments table in Bronze Schema

# %% [markdown]
# #####  List the files form Payment Folder

# %%
# %fs ls 'abfss://gizmoboxsubbu@ourdbpracticeextdl.dfs.core.windows.net/landing/external_data/payments/'

# %%
# %sql
select * from csv.`abfss://gizmoboxsubbu@ourdbpracticeextdl.dfs.core.windows.net/landing/external_data/payments/*.csv`

# %% [markdown]
# ##### 1. Read Payments File

# %%
payments_schema='payment_id INTEGER, order_id INTEGER, payment_timestamp TIMESTAMP, payment_status INTEGER, payment_method STRING'

# %%
from  pyspark.sql.types import StructType,StructField,StringType,IntegerType

py_payments_schema = StructType([
    StructField('payment_id', IntegerType()),
    StructField('order_id', IntegerType()),
    StructField('payment_timestamp', StringType()),
    StructField('payment_status', IntegerType()),
    StructField('payment_method', StringType())
])

# %%
df=(
    spark.read.format('csv')
         .option('delimiter',',')         
        # .schema(payments_schema)
         .load('abfss://gizmoboxsubbu@ourdbpracticeextdl.dfs.core.windows.net/landing/external_data/payments')
)
display(df)

# %% [markdown]
# ##### 2. Create Payments table in Bronze Schema

# %%
df.writeTo('gizmobox_catalog_subbu.bronze.py_payments').createOrReplace()

# %%
# %sql
select * from gizmobox_catalog_subbu.bronze.py_payments
