-- %% [markdown]
-- #### Transform Memberships Data
--
-- 1. Extract customer_id from the file path
-- 2. Write transformed data to the Silver schema

-- %%
select * from gizmobox_catalog_subbu.bronze.v_memberships

-- %% [markdown]
-- ##### 1. Extract customer_id from the file path

-- %%
select 
  regexp_extract(path, '.*/([0-9]+)\\.png$', 1) as customer_id,
  content as membership_card
 from gizmobox_catalog_subbu.bronze.v_memberships

-- %% [markdown]
-- ##### 2.Write transformed data to the Silver schema

-- %%
CREATE TABLE gizmobox_catalog_subbu.silver.memberships
AS
 select 
  regexp_extract(path, '.*/([0-9]+)\\.png$', 1) as customer_id,
  content as membership_card
 from gizmobox_catalog_subbu.bronze.v_memberships

-- %%
select * from gizmobox_catalog_subbu.silver.memberships
