-- %% [markdown]
-- #### Transform Refunds Data
--
-- 1. Extract specific portion of string from refund_reason using split function
-- 2. Extract specific portion of string from refund_reason using regexp_extract function
-- 3. Extract Date and Time from refund_timestamp
-- 4. Cast the columns to correct Data Type
-- 5. Write transformed data to the Silver schema

-- %% [markdown]
-- ##### 1. Extract specific portion of string from refund_reason using split function

-- %%
 select * from asql_gizmobox_subbu_sql_catalog.dbo.refunds

-- %%
select refund_id,
payment_id,
refund_timestamp,
refund_amount,
SPLIT(refund_reason,':')[0] as refund_reason
from asql_gizmobox_subbu_sql_catalog.dbo.refunds

-- %% [markdown]
-- ##### 2. Extract specific portion of string from refund_reason using regexp_extract function

-- %%
select refund_id,
payment_id,
CAST(date_format(refund_timestamp,'yyyy-MM-dd') as date) as refund_date,
date_format(refund_timestamp,'HH:mm:ss') as refund_time,
refund_amount,
regexp_extract(refund_reason,'^([^:]+):',1) as refund_reason,
regexp_extract(refund_reason,'^[^:]+:(.*)$',1) as refund_source
from asql_gizmobox_subbu_sql_catalog.dbo.refunds

-- %% [markdown]
-- ##### 5. Write transformed data to the Silver schema

-- %%
CREATE TABLE gizmobox_catalog_subbu.silver.refunds
AS
select refund_id,
payment_id,
CAST(date_format(refund_timestamp,'yyyy-MM-dd') as date) as refund_date,
date_format(refund_timestamp,'HH:mm:ss') as refund_time,
refund_amount,
regexp_extract(refund_reason,'^([^:]+):',1) as refund_reason,
regexp_extract(refund_reason,'^[^:]+:(.*)$',1) as refund_source
from asql_gizmobox_subbu_sql_catalog.dbo.refunds

-- %%
SELECT * FROM gizmobox_catalog_subbu.silver.refunds
