# %% [markdown]
# #### Extract Data From Orders Data - Complex JSON
# 1. Query Memberships File using binaryFile format
# 2. Create Memberships Table in Bronze Schema

# %% [markdown]
# #####1. Query Memberships File using binaryFile format

# %%
# %fs ls '/Volumes/gizmobox_catalog_subbu/landing/operational_data_volume/memberships/'

# %%
df = spark.read.format('binaryFile').load("/Volumes/gizmobox_catalog_subbu/landing/operational_data_volume/memberships/2024-10/*.png")
display(df)

# %%
df = spark.read.format('binaryFile').load("/Volumes/gizmobox_catalog_subbu/landing/operational_data_volume/memberships/*/*.png")
display(df)

# %% [markdown]
# ##### 2. Create Memberships Table in Bronze Schema

# %%
df.writeTo('gizmobox_catalog_subbu.bronze.py_memberships').createOrReplace()

# %%
# %sql
select * from gizmobox_catalog_subbu.bronze.py_memberships
