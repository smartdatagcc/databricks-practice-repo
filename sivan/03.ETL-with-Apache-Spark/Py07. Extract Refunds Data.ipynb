# %% [markdown]
# **1. Read data from Azure SQL Database table via JDBC**

# %%
df = (
    spark.read.format("jdbc")
        .option("url","")
        .optino("dbtable","Refunds")        
        .option("user","gizmoboxadmin")
        .option("password","Databricks@123")
        .load()
)
