# %% [markdown]
# ### Extract Data from Payment Files
#  1. Read Payment File
#  2. Create Payments Table in the Bronze schema

# %% [markdown]
# ### 1. List the files from Payment folder

# %%
# %fs ls 'abfss://gizmoboxsivan@ourdbpracticeextdl.dfs.core.windows.net/landing/external_data/payments'

# %% [markdown]
# **2.Read Payment File - with SQL Schema**

# %%
payment_schema = 'payment_id INTEGER, order_id INTEGER, payment_timestamp TIMESTAMP, payment_status INTEGER, payment_method STRING'

# %%
df = (
    spark.read.format('csv')
        .schema(payment_schema)
        .option('delimiter',',')
        .load('abfss://gizmoboxsivan@ourdbpracticeextdl.dfs.core.windows.net/landing/external_data/payments')
)
display(df)

# %% [markdown]
# **2.Read Payment File - with PySpark Schema**

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, TimestampType
py_payment_schema = StructType([
    StructField('payment_id', IntegerType(), True),
    StructField('order_id', IntegerType(), True),
    StructField('payment_timestamp', TimestampType(), True),
    StructField('payment_status', StringType(), True),
    StructField('payment_method', StringType(), True)
])

# %%
df = (
    spark.read.format('csv')
    .option('delimiter',',')
    .schema(py_payment_schema)
    .load('abfss://gizmoboxsivan@ourdbpracticeextdl.dfs.core.windows.net/landing/external_data/payments')
)
display(df)

# %% [markdown]
# **3. Create a table in Bronze schema**

# %%
df.writeTo("gizmobox_sivan.bronze.py_payments").createOrReplace()

# %%
df1 = spark.table("gizmobox_sivan.bronze.py_payments")
display(df1)
