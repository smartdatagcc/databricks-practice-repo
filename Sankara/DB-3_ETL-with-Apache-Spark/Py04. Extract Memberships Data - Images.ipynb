# %% [markdown]
# ### Extract Data from Memberships - Images Files
#  1. Query Membership File using Binary Format
#  2. Crate Memberships View in Bronze schema

# %% [markdown]
# ### 1. Query Memberships folder using Binary Format

# %%
# %fs ls '/Volumes/gizmobox_sivan/landing/operational_data_volume/memberships/'

# %%
df = spark.read.format("binaryFile").load("/Volumes/gizmobox_sivan/landing/operational_data_volume/memberships/*")
display(df);

# %%
df = spark.read.format("binaryFile").load("/Volumes/gizmobox_sivan/landing/operational_data_volume/memberships/*/*.png")
display(df);

# %% [markdown]
# ### 2. Create Memberships view in Bronze Schema

# %%
df.writeTo("gizmobox_sivan.bronze.py_memberships").createOrReplace();

# %%
# %sql
select * from gizmobox_sivan.bronze.py_memberships;
