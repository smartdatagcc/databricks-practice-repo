-- %% [markdown]
-- ### Extract Data from Memberships - Images Files
--  1. Query Membership File using Binary Format
--  2. Crate Memberships View in Bronze schema

-- %% [markdown]
-- ### 1. Query Memberships folder using Binary Format

-- %%
%fs ls '/Volumes/gizmobox_sankara/landing/operational_volume/memberships/'

-- %%
select * from binaryFile.`/Volumes/gizmobox_sankara/landing/operational_volume/memberships/*`

-- %%
select * from binaryFile.`/Volumes/gizmobox_sankara/landing/operational_volume/memberships/*/*.png`

-- %% [markdown]
-- ### 2. Create Memberships view in Bronze Schema

-- %%
CREATE OR REPLACE VIEW gizmobox_sivan.bronze.v_memberships
AS
select * from binaryFile.`/Volumes/gizmobox_sivan/landing/operational_data_volume/memberships/*/*.png`;

-- %%
select * from gizmobox_sivan.bronze.v_memberships;
