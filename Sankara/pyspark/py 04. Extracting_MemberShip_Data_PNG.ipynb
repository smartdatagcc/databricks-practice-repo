# %% [markdown]
# # EXtract_MemberShip_PNG USING BINARY_FORMAT
# ### 1.Query the data using Binary Fomart
# ### 2. Creating View in Bronze Schema for MemberShip

# %%
df = spark.read.format("binaryFile").load("/Volumes/gizmobox_nara/landing/operational_volume/memberships/*.png")
display(df)

# %%
df.writeTo("gizmobox_nara.bronze.py1_memberships").createOrReplace()

# %%
df_read  = spark.table("gizmobox_nara.bronze.py1_memberships")
display(df_read)

# %%
# %fs ls '/Volumes/gizmobox_nara/landing/operational_volume/memberships/'

# %%
# %sql
SELECT * FROM binaryfile.`/Volumes/gizmobox_nara/landing/operational_volume/memberships/*`

# %% [markdown]
# # CREATING A VIEW FOR MEMBERSHIP IN BRONZE

# %%
# %sql
select * from gizmobox_nara.bronze.py_memberships

# %%
# %sql
SELECT * FROM gizmobox_nara.bronze.v_memberships
