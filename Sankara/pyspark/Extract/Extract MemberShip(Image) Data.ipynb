-- %% [markdown]
-- **1. Create View For Bronze Schema**

-- %%
%python
df = spark.read.format('binaryFile').load('/Volumes/gizmobox_sankara/landing/operational_volume/memberships/*.png')
display(df)

-- %%
%python
df.writeTo("gizmobox_sankara.bronze.py_membership").createOrReplace();

-- %%
%sql
SELECT * FROM gizmobox_sankara.bronze.py_membership;
