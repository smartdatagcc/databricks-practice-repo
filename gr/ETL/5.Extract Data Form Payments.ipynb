-- %% [markdown]
-- **Extract Data Form Payments**

-- %% [markdown]
-- **List The Payment Files**

-- %%
%fs ls 'abfs://gizmoboxgr@ourdbpracticeextdl.dfs.core.windows.net/landing/external_data/payments/'

-- %% [markdown]
-- **Create External Table**

-- %%
CREATE TABLE IF NOT EXISTS gizmobox_gr.bronze.payments
(paymentId INTEGER,orderId INTEGER,paymetOn TIMESTAMP,paymentStatus INTEGER,paymentMethod STRING)
USING csv
OPTIONS(
    header "true",
    delimeter ","
)
LOCATION 'abfss://gizmoboxgr@ourdbpracticeextdl.dfs.core.windows.net/landing/external_data/payments';

-- %%
SELECT * FROM gizmobox_gr.bronze.payments;
DESCRIBE EXTENDED gizmobox_gr.bronze.payments;

-- %% [markdown]
-- **Add/Update/Delete Files- Refresh the table meta data**

-- %%
REFRESH TABLE gizmobox_gr.bronze.payments;

-- %% [markdown]
-- **Droping Table**

-- %%
DROP TABLE IF EXISTS gizmobox_gr.bronze.payments;
