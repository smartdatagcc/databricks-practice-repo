-- %% [markdown]
-- **1. Create View For Bronze Schema**

-- %%
%python
dfMemberShip=spark.read.format("binaryFile").load("/Volumes/gizmobox_gr/landing/operational_data/memberships/*/*.png")
display(dfMemberShip)

-- %%
%python
dfMemberShip.writeTo("gizmobox_gr.bronze.py_membership").createOrReplace();

%sql
SELECT * FROM gizmobox_gr.bronze.py_membership;
