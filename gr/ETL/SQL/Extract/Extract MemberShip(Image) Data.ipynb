-- %% [markdown]
-- **1. Create View For Bronze Schema**

-- %%
CREATE OR REPLACE VIEW gizmobox_gr.bronze.v_membership AS
SELECT *,_metadata.file_path FROM binaryFile.`/Volumes/gizmobox_gr/landing/operational_data/memberships/*/*.png`

-- %%
SELECT * FROM gizmobox_gr.bronze.v_membership
