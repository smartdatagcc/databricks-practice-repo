-- %% [markdown]
-- **Monthly Order Summary**

-- %%
CREATE OR REPLACE TABLE gizmobox_gr.gold.orders_summary_monthly
SELECT date_format(transaction_timestamp, 'yyyy-MM') as order_month,
customer_id,
COUNT(DISTINCT ORDER_ID) as total_orders,
SUM(price) as total_revenue,
SUM(quantity) as total_units
FROM gizmobox_gr.silver.orders
GROUp BY order_month,customer_id;

-- %%
SELECT * FROM gizmobox_gr.gold.orders_summary_monthly;
